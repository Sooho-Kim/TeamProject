# %%
pip install -U selenium
# Out:
# Requirement already up-to-date: selenium in c:\users\sooho\anaconda3\lib\site-packages (3.141.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os
import urllib.request
from bs4 import BeautifulSoup

# %%
#키워드 입력하세요
image_keyword=['2% 복숭아','2% 복숭아 캔']

# %% [markdown]
# # Daum

# %%
execution_path = os.getcwd()
driver = webdriver.Chrome(os.path.join(execution_path, 'chromedriver.exe'))

# %%
def fetch_list_url_daum():
    params = []
    imgList = soup.find_all("img", class_="thumb_img")
    for im in imgList :
        params.append(im["src"])
        print(params)
    return params

def fetch_detail_url_daum():
    params = fetch_list_url_daum()
    a=1
    for p in params:
        urllib.request.urlretrieve(p, image_path+'/'+str(a)+".jpg")
        a +=1

# %%
for i in image_keyword:
    if not(os.path.isdir("Daum"+i)):
        os.makedirs(os.path.join(execution_path,"Daum"+ i))
    image_path = os.path.join(execution_path, "Daum"+i)
    driver.get("https://search.daum.net/search?nil_suggest=btn&w=img&DA=SBC&q=")
    driver.find_element_by_xpath('//*[@id="daumSearch"]/fieldset/div/div').click()
    driver.find_element_by_class_name('tf_keyword').send_keys(i) #검색어 설정
    driver.find_element_by_xpath('//*[@id="daumSearch"]/fieldset/div/div/button[2]').click()
    while True :
        j=0
        while j<4:
            j+=1
            driver.find_element_by_xpath("//body").send_keys(Keys.END)
            time.sleep(1)
        try:
            driver.find_element_by_xpath('//*[@id="imgColl"]/div[5]/a[1]').click()
        except:
            break
    html = driver.page_source
    soup = BeautifulSoup(html,"html.parser")
    
    fetch_detail_url_daum()
    print(i, "가 모두 저장되었습니다")
driver.quit()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 2% 복숭아 가 모두 저장되었습니다
# ['https://search1.kakaocdn.net/argon/0x200_85_hr/LxpcgznsbJu']
# ['https://search1.kakaocdn.net/argon/0x200_85_hr/LxpcgznsbJu', 'https://search2.kakaocdn.net/argon/0x200_85_hr/JBHfNAZTj2B']
# ['https://search1.kakaocdn.net/argon/0x200_85_hr/LxpcgznsbJu', 'https://search2.kakaocdn.net/argon/0x200_85_hr/JBHfNAZTj2B', 'https://search2.kakaocdn.net/argon/0x200_85_hr/DTqfo2mBm6J']
# ['https://search1.kakaocdn.net/argon/0x200_85_hr/LxpcgznsbJu', 'https://search2.kakaocdn.net/argon/0x200_85_hr/JBHfNAZTj2B', 'https://search2.kakaocdn.net/argon/0x200_85_hr/DTqfo2mBm6J', 'https://search3.kakaocdn.net/argon/0x200_85_hr/7ETNTVsoHMQ']
# ...

# %% [markdown]
# # Naver

# %%
execution_path = os.getcwd()
driver = webdriver.Chrome(os.path.join(execution_path, 'chromedriver.exe'))

# %%
def fetch_list_url_naver():
    params = []
    imgList = soup.find_all("img", class_="_img")
    for im in imgList :
        params.append(im["src"])
        print(params)
    return params

def fetch_detail_url_naver():
    params = fetch_list_url_naver()
    a=1
    for p in params:
        urllib.request.urlretrieve(p, image_path+'/'+str(a)+".jpg")
        a +=1

# %%
for i in image_keyword:
    if not(os.path.isdir("Naver"+i)):
        os.makedirs(os.path.join(execution_path,"Naver"+ i))
    image_path = os.path.join(execution_path, "Naver"+i)
    driver.get("https://search.naver.com/search.naver?where=image&sm=tab_jum&query=")
    driver.find_element_by_xpath('//*[@id="nx_query"]').click()
    driver.find_element_by_class_name('box_window').send_keys(i) #검색어 설정
    driver.find_element_by_xpath('//*[@id="nx_search_form"]/fieldset/button/span').click()
    while True :
        j=0
        while j<7:
            j+=1
            driver.find_element_by_xpath("//body").send_keys(Keys.END)
            time.sleep(1)
        try:
            driver.find_element_by_xpath('//*[@id="_sau_imageTab"]/div[2]/div[8]/a/span').click()
        except:
            break
    html = driver.page_source
    soup = BeautifulSoup(html,"html.parser")
    
    fetch_detail_url_naver()
    print(i, "가 모두 저장되었습니다")
driver.quit()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 2% 부족할때 가 모두 저장되었습니다
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 2% 복숭아 가 모두 저장되었습니다
